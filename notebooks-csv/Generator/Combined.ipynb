# %%
import requests
import PyPDF2
from io import BytesIO
import pandas as pd
import os
from dotenv import load_dotenv
from pathlib import Path
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
import glob

csv_files = glob.glob('./Generated_Solution/**/*.csv', recursive=True)
df = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)

# %%
df
# Out:
#       writer                    problem_id  submission_id  \
# 0         AI                        abacus            NaN
# 1         AI                adjacency_list            NaN
# 2         AI                        amogus            NaN
# 3         AI                     bookshelf            NaN
# 4         AI                    c1_bkk60_1            NaN
# ...      ...                           ...            ...
# 10632     AI              tumso20_penguin2            NaN
# 10633     AI         tumso20_shibuyajihen2            NaN
# 10634     AI  tumso20_simplepotatolanguage            NaN
# 10635     AI                tumso20_space2            NaN
# 10636     AI         tumso20_tetrisbattle2            NaN
#
#                          website  \
# 0      https://firefly.gchan.moe
# 1      https://firefly.gchan.moe
# 2      https://firefly.gchan.moe
# 3      https://firefly.gchan.moe
# 4      https://firefly.gchan.moe
# ...                          ...
# ...

# %%
df['website'].value_counts()
# Out:
# website
# https://codeforces.com       5175
# https://programming.in.th    4015
# https://firefly.gchan.moe    1447
# Name: count, dtype: int64

# %%
df[df['website'].str.contains('https://codeforces.com')].to_csv('codeforces1.csv', index=False)
df[df['website'].str.contains('https://programming.in.th')].to_csv('programming1.csv', index=False)
df[df['website'].str.contains('https://firefly.gchan.moe')].to_csv('graderchan1.csv', index=False)
